# %%
# NBVAL_SKIP
# !wget -O NBA_2021.csv https://raw.githubusercontent.com/nogibjj/IDS706_pandas_description_hw2/refs/heads/main/NBA_2021.csv
# Out:
# --2024-11-03 01:41:29--  https://raw.githubusercontent.com/nogibjj/IDS706_pandas_description_hw2/refs/heads/main/NBA_2021.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90002 (88K) [text/plain]
# Saving to: ‘NBA_2021.csv’
#
# NBA_2021.csv        100%[===================>]  87.89K  --.-KB/s    in 0.02s
#
# 2024-11-03 01:41:29 (3.59 MB/s) - ‘NBA_2021.csv’ saved [90002/90002]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("NBA_2021.csv")

# %%
df = df.dropna()

# %%
df.head()
# Out:
#               Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0   Precious Achiuwa  PF   21  MIA  61   4  12.1  2.0   3.7  0.544  ...
# 2       Steven Adams   C   27  NOP  58  58  27.7  3.3   5.3  0.614  ...
# 3        Bam Adebayo   C   23  MIA  64  64  33.5  7.1  12.5  0.570  ...
# 4  LaMarcus Aldridge   C   35  TOT  26  23  25.9  5.4  11.4  0.473  ...
# 5  LaMarcus Aldridge   C   35  SAS  21  18  25.9  5.5  11.8  0.464  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.509  1.2  2.2  3.4  0.5  0.3  0.5  0.7  1.5   5.0
# 2  0.444  3.7  5.2  8.9  1.9  0.9  0.7  1.3  1.9   7.6
# 3  0.799  2.2  6.7  9.0  5.4  1.2  1.0  2.6  2.3  18.7
# 4  0.872  0.7  3.8  4.5  1.9  0.4  1.1  1.0  1.8  13.5
# 5  0.838  0.8  3.7  4.5  1.7  0.4  0.9  1.0  1.7  13.7
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 647 entries, 0 to 704
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  647 non-null    object
#  1   Pos     647 non-null    object
#  2   Age     647 non-null    int64
#  3   Tm      647 non-null    object
#  4   G       647 non-null    int64
#  5   GS      647 non-null    int64
#  6   MP      647 non-null    float64
#  7   FG      647 non-null    float64
#  8   FGA     647 non-null    float64
#  9   FG%     647 non-null    float64
#  10  3P      647 non-null    float64
#  11  3PA     647 non-null    float64
#  12  3P%     647 non-null    float64
#  13  2P      647 non-null    float64
#  14  2PA     647 non-null    float64
#  15  2P%     647 non-null    float64
#  16  eFG%    647 non-null    float64
#  17  FT      647 non-null    float64
#  18  FTA     647 non-null    float64
#  19  FT%     647 non-null    float64
#  20  ORB     647 non-null    float64
#  21  DRB     647 non-null    float64
#  22  TRB     647 non-null    float64
#  23  AST     647 non-null    float64
#  24  STL     647 non-null    float64
#  25  BLK     647 non-null    float64
#  26  TOV     647 non-null    float64
#  27  PF      647 non-null    float64
#  28  PTS     647 non-null    float64
# dtypes: float64(23), int64(3), object(3)
# memory usage: 151.6+ KB

# %%
df.describe()
# Out:
#               Age           G          GS          MP          FG         FGA  \
# count  647.000000  647.000000  647.000000  647.000000  647.000000  647.000000
# mean    25.981453   39.591963   18.086553   20.352241    3.346059    7.354096
# std      4.137680   20.329647   21.907459    8.723955    2.254705    4.662423
# min     19.000000    1.000000    0.000000    2.000000    0.000000    0.500000
# 25%     23.000000   22.000000    1.000000   13.700000    1.650000    3.800000
# 50%     26.000000   41.000000    7.000000   20.100000    2.800000    6.200000
# 75%     29.000000   58.000000   32.000000   27.500000    4.500000    9.700000
# max     38.000000   72.000000   72.000000   37.600000   11.200000   23.000000
#
#               FG%          3P         3PA         3P%  ...         FT%  \
# count  647.000000  647.000000  647.000000  647.000000  ...  647.000000
# mean     0.446252    1.036631    2.914992    0.319535  ...    0.754878
# std      0.087204    0.872403    2.197629    0.123077  ...    0.143730
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      0.401000    0.300000    1.200000    0.278500  ...    0.691000
# 50%      0.440000    0.800000    2.400000    0.341000  ...    0.778000
# 75%      0.486500    1.600000    4.400000    0.388000  ...    0.845000
# max      0.769000    5.300000   12.700000    1.000000  ...    1.000000
#
#               ORB         DRB         TRB         AST         STL         BLK  \
# count  647.000000  647.000000  647.000000  647.000000  647.000000  647.000000
# mean     0.803709    2.876198    3.679444    2.065842    0.645904    0.412674
# std      0.684674    1.768171    2.294446    1.830780    0.383294    0.386731
# min      0.000000    0.200000    0.300000    0.000000    0.000000    0.000000
# 25%      0.300000    1.600000    2.000000    0.800000    0.400000    0.100000
# 50%      0.600000    2.600000    3.200000    1.500000    0.600000    0.300000
# 75%      1.000000    3.800000    4.800000    2.600000    0.900000    0.600000
# max      4.100000   10.100000   13.500000   11.700000    2.100000    3.400000
#
#               TOV          PF         PTS
# count  647.000000  647.000000  647.000000
# mean     1.121793    1.674498    9.124730
# std      0.801085    0.721807    6.221197
# min      0.000000    0.000000    0.400000
# 25%      0.600000    1.100000    4.600000
# 50%      0.900000    1.700000    7.500000
# 75%      1.450000    2.100000   12.150000
# max      4.800000    4.000000   32.000000
#
# [8 rows x 26 columns]

# %%
top_scorers_per_team = (
    df[df["G"] > 20]
    .sort_values(["Tm", "PTS"], ascending=[True, False])
    .groupby("Tm")
    .head(1)
    .reset_index(drop=True)
).sort_values("PTS", ascending=False)
print(top_scorers_per_team[["Tm", "Player", "PTS"]])
# Out:
#      Tm                   Player   PTS
# 9   GSW            Stephen Curry  32.0
# 30  WAS             Bradley Beal  31.3
# 24  POR           Damian Lillard  28.8
# 22  PHI              Joel Embiid  28.5
# 16  MIL    Giannis Antetokounmpo  28.1
# 6   DAL              Luka Dončić  27.7
# 3   CHI              Zach LaVine  27.4
# 18  NOP          Zion Williamson  27.0
# 2   BRK             Kevin Durant  26.9
# 1   BOS             Jayson Tatum  26.4
# 29  UTA         Donovan Mitchell  26.4
# 7   DEN             Nikola Jokić  26.4
# 23  PHO             Devin Booker  25.6
# 0   ATL               Trae Young  25.3
# 25  SAC             De'Aaron Fox  25.2
# 13  LAL             LeBron James  25.0
# 12  LAC            Kawhi Leonard  24.8
# 17  MIN       Karl-Anthony Towns  24.8
# 28  TOT             James Harden  24.6
# 21  ORL           Nikola Vučević  24.5
# 5   CLE            Collin Sexton  24.3
# 19  NYK            Julius Randle  24.1
# 20  OKC  Shai Gilgeous-Alexander  23.7
# 8   DET             Jerami Grant  22.3
# 26  SAS            DeMar DeRozan  21.6
# 15  MIA             Jimmy Butler  21.5
# 27  TOR            Pascal Siakam  21.4
# 11  IND          Malcolm Brogdon  21.2
# 10  HOU           Christian Wood  21.0
# 4   CHO             Terry Rozier  20.4
# 14  MEM                Ja Morant  19.1

# %%
plt.figure(figsize=(12, 8))
plt.bar(top_scorers_per_team["Player"], top_scorers_per_team["PTS"], color="skyblue")
plt.xlabel("Player")
plt.ylabel("Points (PTS)")
plt.title("Top Scorers Per Team (Minimum 20 Games Played)")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
df["Efficiency_Rating"] = (
    df["PTS"]
    + df["TRB"]
    + df["AST"]
    + df["STL"]
    + df["BLK"]
    - (df["FGA"] - df["FG"])
    - (df["FTA"] - df["FT"])
    - df["TOV"]
)
top_efficiency_players = df[df["G"] > 20][["Player", "Efficiency_Rating"]].nlargest(
    10, "Efficiency_Rating"
)
print(top_efficiency_players)
# Out:
#                     Player  Efficiency_Rating
# 344           Nikola Jokić               35.9
# 17   Giannis Antetokounmpo               33.3
# 260           James Harden               32.3
# 258           James Harden               31.4
# 189            Joel Embiid               31.1
# 675      Russell Westbrook               29.6
# 183           Kevin Durant               29.5
# 151          Stephen Curry               29.3
# 577       Domantas Sabonis               29.1
# 171            Luka Dončić               28.9

# %%
plt.barh(
    top_efficiency_players["Player"], top_efficiency_players["Efficiency_Rating"], color="salmon"
)
plt.xlabel("Efficiency Rating")
plt.ylabel("Player")
plt.title("Top 10 Players by Efficiency Rating (Minimum 20 Games Played)")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
